# %% [markdown]
# # Detecting clones using the dataset

# %% [markdown]
# ## Embeddings

# %%
# embeddings word2vec fasttext Piotr Bojanowski, Edouard Grave, Armand Joulin, et Tomas Mikolov, Enriching word vectors with subword information, Transactions of the association for computational linguistics 5 (2017), 135–146.
# https://link.springer.com/article/10.1007/s10270-024-01250-5

# %%
# Requirements: 
# !pip install --upgrade transformers datasets
# !pip install transformers[torch] or !pip install 'accelerate>=0.26.0

import warnings
warnings.filterwarnings("ignore") 
from src.fine_tune import finetune_clone_model
FINAL_DATASET = "../results/bigcodebench_clone_dataset.json" 
codebert = "microsoft/codebert-base"
codet5 = "Salesforce/codet5-base" 
model_name = codet5  
epochs = 3
batch_size = 8

if(model_name == codebert):
    output_dir = "../results/clone_detection/codebert"
elif(model_name == codet5):
    output_dir = "../results/clone_detection/codet5"
# Run training
trainer, tokenizer = finetune_clone_model(
    dataset_path=FINAL_DATASET,
    model_name=model_name,
    output_dir=output_dir,
    epochs=epochs,
    batch_size=batch_size,
)
# Out:
# Some weights of T5ForSequenceClassification were not initialized from the model checkpoint at Salesforce/codet5-base and are newly initialized: ['classification_head.dense.bias', 'classification_head.dense.weight', 'classification_head.out_proj.bias', 'classification_head.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='54' max='138' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 54/138 14:53 < 24:03, 0.06 it/s, Epoch 1.15/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.074263</td>
#       <td>0.989011</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 19
#      17     output_dir = "../results/clone_detection/codet5"
#      18 # Run training
# ---> 19 trainer, tokenizer = finetune_clone_model(
#      20     dataset_path=FINAL_DATASET,
#      21     model_name=model_name,
#      22     output_dir=output_dir,
#      23     epochs=epochs,
#      24     batch_size=batch_size,
#      25 )
#
# Cell In[10], line 108, in finetune_clone_model(dataset_path, model_name, output_dir, epochs, batch_size)
#      98     return {"accuracy": accuracy}
#     100 trainer = Trainer(
#     101     model=model,
#     102     args=training_args,
#    (...)
#     105     compute_metrics=compute_metrics,
#     106 )
# --> 108 trainer.train()
#     109 eval_results = trainer.evaluate()
#     110 print("✅ Validation Results:", eval_results)
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\transformers\trainer.py:2325, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2323         hf_hub_utils.enable_progress_bars()
#    2324 else:
# -> 2325     return inner_training_loop(
#    2326         args=args,
#    2327         resume_from_checkpoint=resume_from_checkpoint,
#    2328         trial=trial,
#    2329         ignore_keys_for_eval=ignore_keys_for_eval,
#    2330     )
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\transformers\trainer.py:2674, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2667 context = (
#    2668     functools.partial(self.accelerator.no_sync, model=model)
#    2669     if i != len(batch_samples) - 1
#    2670     and self.accelerator.distributed_type != DistributedType.DEEPSPEED
#    2671     else contextlib.nullcontext
#    2672 )
#    2673 with context():
# -> 2674     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2676 if (
#    2677     args.logging_nan_inf_filter
#    2678     and not is_torch_xla_available()
#    2679     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2680 ):
#    2681     # if loss is nan or inf simply add the average of previous logged losses
#    2682     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\transformers\trainer.py:4020, in Trainer.training_step(self, model, inputs, num_items_in_batch)
#    4017     return loss_mb.reduce_mean().detach().to(self.args.device)
#    4019 with self.compute_loss_context_manager():
# -> 4020     loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#    4022 del inputs
#    4023 if (
#    4024     self.args.torch_empty_cache_steps is not None
#    4025     and self.state.global_step % self.args.torch_empty_cache_steps == 0
#    4026 ):
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\transformers\trainer.py:4110, in Trainer.compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#    4108         kwargs["num_items_in_batch"] = num_items_in_batch
#    4109     inputs = {**inputs, **kwargs}
# -> 4110 outputs = model(**inputs)
#    4111 # Save past state if it exists
#    4112 # TODO: this needs to be fixed and made cleaner later.
#    4113 if self.args.past_index >= 0:
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\transformers\models\t5\modeling_t5.py:2047, in T5ForSequenceClassification.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    2040         raise ValueError(
#    2041             "If no `decoder_input_ids` or `decoder_inputs_embeds` are "
#    2042             "passed, `input_ids` cannot be `None`. Please pass either "
#    2043             "`input_ids` or `decoder_input_ids` or `decoder_inputs_embeds`."
#    2044         )
#    2045     decoder_input_ids = self._shift_right(input_ids)
# -> 2047 outputs = self.transformer(
#    2048     input_ids,
#    2049     attention_mask=attention_mask,
#    2050     decoder_input_ids=decoder_input_ids,
#    2051     decoder_attention_mask=decoder_attention_mask,
#    2052     head_mask=head_mask,
#    2053     decoder_head_mask=decoder_head_mask,
#    2054     cross_attn_head_mask=cross_attn_head_mask,
#    2055     encoder_outputs=encoder_outputs,
#    2056     inputs_embeds=inputs_embeds,
#    2057     decoder_inputs_embeds=decoder_inputs_embeds,
#    2058     use_cache=use_cache,
#    2059     output_attentions=output_attentions,
#    2060     output_hidden_states=output_hidden_states,
#    2061     return_dict=return_dict,
#    2062 )
#    2063 sequence_output = outputs[0]
#    2065 eos_mask = input_ids.eq(self.config.eos_token_id).to(sequence_output.device)
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\transformers\models\t5\modeling_t5.py:1477, in T5Model.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1475 # Encode if needed (training, first prediction pass)
#    1476 if encoder_outputs is None:
# -> 1477     encoder_outputs = self.encoder(
#    1478         input_ids=input_ids,
#    1479         attention_mask=attention_mask,
#    1480         inputs_embeds=inputs_embeds,
#    1481         head_mask=head_mask,
#    1482         output_attentions=output_attentions,
#    1483         output_hidden_states=output_hidden_states,
#    1484         return_dict=return_dict,
#    1485     )
#    1486 elif return_dict and not isinstance(encoder_outputs, BaseModelOutput):
#    1487     encoder_outputs = BaseModelOutput(
#    1488         last_hidden_state=encoder_outputs[0],
#    1489         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1490         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1491     )
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\transformers\models\t5\modeling_t5.py:1100, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1097 if output_hidden_states:
#    1098     all_hidden_states = all_hidden_states + (hidden_states,)
# -> 1100 layer_outputs = layer_module(
#    1101     hidden_states,
#    1102     causal_mask,
#    1103     position_bias,
#    1104     encoder_hidden_states,
#    1105     encoder_extended_attention_mask,
#    1106     encoder_decoder_position_bias,  # as a positional argument for gradient checkpointing
#    1107     layer_head_mask=layer_head_mask,
#    1108     cross_attn_layer_head_mask=cross_attn_layer_head_mask,
#    1109     past_key_values=past_key_values,
#    1110     use_cache=use_cache,
#    1111     output_attentions=output_attentions,
#    1112     return_dict=return_dict,
#    1113     cache_position=cache_position,
#    1114 )
#    1116 hidden_states = layer_outputs[0]
#    1118 # We share the position biases between the layers - the first layer store them
#    1119 # layer_outputs = hidden-states, key-value-states (self-attention position bias), (self-attention weights),
#    1120 # (cross-attention position bias), (cross-attention weights)
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\transformers\modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning_once(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\transformers\utils\deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\transformers\models\t5\modeling_t5.py:687, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_values, use_cache, output_attentions, return_dict, cache_position)
#     670 @deprecate_kwarg("past_key_value", new_name="past_key_values", version="4.58")
#     671 def forward(
#     672     self,
#    (...)
#     685     cache_position=None,
#     686 ):
# --> 687     self_attention_outputs = self.layer[0](
#     688         hidden_states,
#     689         attention_mask=attention_mask,
#     690         position_bias=position_bias,
#     691         layer_head_mask=layer_head_mask,
#     692         past_key_values=past_key_values,
#     693         use_cache=use_cache,
#     694         output_attentions=output_attentions,
#     695         cache_position=cache_position,
#     696     )
#     697     hidden_states = self_attention_outputs[0]
#     698     attention_outputs = self_attention_outputs[1:]  # Keep self-attention outputs and relative position weights
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\transformers\utils\deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\transformers\models\t5\modeling_t5.py:603, in T5LayerSelfAttention.forward(self, hidden_states, attention_mask, position_bias, layer_head_mask, past_key_values, use_cache, output_attentions, cache_position)
#     590 @deprecate_kwarg("past_key_value", new_name="past_key_values", version="4.58")
#     591 def forward(
#     592     self,
#    (...)
#     600     cache_position=None,
#     601 ):
#     602     normed_hidden_states = self.layer_norm(hidden_states)
# --> 603     attention_output = self.SelfAttention(
#     604         normed_hidden_states,
#     605         mask=attention_mask,
#     606         position_bias=position_bias,
#     607         layer_head_mask=layer_head_mask,
#     608         past_key_values=past_key_values,
#     609         use_cache=use_cache,
#     610         output_attentions=output_attentions,
#     611         cache_position=cache_position,
#     612     )
#     613     hidden_states = hidden_states + self.dropout(attention_output[0])
#     614     outputs = (hidden_states,) + attention_output[1:]  # add attentions if we output them
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\transformers\utils\deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\transformers\models\t5\modeling_t5.py:562, in T5Attention.forward(self, hidden_states, mask, key_value_states, position_bias, past_key_values, layer_head_mask, query_length, use_cache, output_attentions, cache_position)
#     560 # (batch_size, n_heads, seq_length, key_length)
#     561 attn_weights = nn.functional.softmax(scores.float(), dim=-1).type_as(scores)
# --> 562 attn_weights = nn.functional.dropout(attn_weights, p=self.dropout, training=self.training)
#     564 # Mask heads if we want to
#     565 if layer_head_mask is not None:
#
# File c:\Users\lamp6\anaconda3\Lib\site-packages\torch\nn\functional.py:1422, in dropout(input, p, training, inplace)
#    1419 if p < 0.0 or p > 1.0:
#    1420     raise ValueError(f"dropout probability has to be between 0 and 1, but got {p}")
#    1421 return (
# -> 1422     _VF.dropout_(input, p, training) if inplace else _VF.dropout(input, p, training)
#    1423 )
#
# KeyboardInterrupt:
