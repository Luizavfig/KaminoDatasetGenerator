# %% [markdown]
# ## Commands to install BigCodeBench

# %%
# !pip install datasets huggingface_hub
# Out:
# Requirement already satisfied: datasets in c:\users\lamp6\appdata\roaming\python\python313\site-packages (4.0.0)
# Requirement already satisfied: huggingface_hub in c:\users\lamp6\appdata\roaming\python\python313\site-packages (0.34.4)
# Requirement already satisfied: filelock in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from datasets) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from datasets) (2.3.1)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from datasets) (2.3.2)
# Requirement already satisfied: requests>=2.32.2 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from datasets) (2.32.5)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: packaging in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from huggingface_hub) (4.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: idna>=2.0 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from requests>=2.32.2->datasets) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from requests>=2.32.2->datasets) (2025.8.3)
# Requirement already satisfied: colorama in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\lamp6\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
from huggingface_hub import login
from dotenv import load_dotenv
import os 

load_dotenv()  # loads variables from .env
token = os.getenv("HF_TOKEN") 
login(token)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
from datasets import load_dataset

ds = load_dataset("bigcode/bigcodebench")
print(ds)
# Out:
# DatasetDict({
#     v0.1.0_hf: Dataset({
#         features: ['task_id', 'complete_prompt', 'instruct_prompt', 'canonical_solution', 'code_prompt', 'test', 'entry_point', 'doc_struct', 'libs'],
#         num_rows: 1140
#     })
#     v0.1.1: Dataset({
#         features: ['task_id', 'complete_prompt', 'instruct_prompt', 'canonical_solution', 'code_prompt', 'test', 'entry_point', 'doc_struct', 'libs'],
#         num_rows: 1140
#     })
#     v0.1.2: Dataset({
#         features: ['task_id', 'complete_prompt', 'instruct_prompt', 'canonical_solution', 'code_prompt', 'test', 'entry_point', 'doc_struct', 'libs'],
#         num_rows: 1140
#     })
#     v0.1.3: Dataset({
#         features: ['task_id', 'complete_prompt', 'instruct_prompt', 'canonical_solution', 'code_prompt', 'test', 'entry_point', 'doc_struct', 'libs'],
#         num_rows: 1140
#     })
#     v0.1.4: Dataset({
#         features: ['task_id', 'complete_prompt', 'instruct_prompt', 'canonical_solution', 'code_prompt', 'test', 'entry_point', 'doc_struct', 'libs'],
#         num_rows: 1140
#     })
# })
