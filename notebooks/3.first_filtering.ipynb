# %% [markdown]
# ## Codebleu filter, and running tests

# %%
from src.steps.filtering import run_codebleu_filtering, run_tests

run_codebleu_filtering()
run_tests()
# Out:
# Evaluating Entry 1/12 | id=BigCodeBench/58
# Clone 1: CodeBLEU already computed (0.7833)
# Clone 2: CodeBLEU already computed (0.6144)
# Clone 3: CodeBLEU already computed (0.7833)
# Clone 4: CodeBLEU already computed (0.2500)
# Clone 5: CodeBLEU already computed (0.8199)
# Clone 6: CodeBLEU already computed (0.5939)
# Clone 7: CodeBLEU already computed (0.8199)
# Clone 8: CodeBLEU already computed (0.5036)
# Clone 9: CodeBLEU already computed (0.4236)
# Clone 10: CodeBLEU already computed (0.3486)
# Clone 11: CodeBLEU already computed (0.3269)
# Clone 12: CodeBLEU already computed (0.6866)
# Clone 13: CodeBLEU already computed (0.2480)
# Clone 14: CodeBLEU already computed (0.5826)
# Clone 15: CodeBLEU already computed (0.2500)
# Clone 16: CodeBLEU already computed (0.2143)
# Clone 17: CodeBLEU already computed (0.2500)
# Clone 18: CodeBLEU already computed (0.1845)
# Clone 19: CodeBLEU already computed (0.2500)
# Clone 20: CodeBLEU already computed (0.2342)
# ...
